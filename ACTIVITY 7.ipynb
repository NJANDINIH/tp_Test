# %%
#important libraries that should be imported together with seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Loading data frame
df = pd.read_csv('C:/Users/user/Desktop/Test 2 prep/dataset - 2020-09-24.csv')

# %%
#Apply the default theme
sns.set_theme()

# %%
#Applying styles
sns.set_style("darkgrid")

# %%
sns.lineplot(x ="Wins", y = "Shots on target", data=df)
plt.show()

# %%
sns.set_style("whitegrid")
sns.lineplot(x = "Shots" , y = "Big chances missed" , color = 'black' , data=df)
plt.show()

# %%
 sns.set_context("talk")
sns.lineplot(x = "Shots", y = "Hit woodwork", data=df)
plt.show()

# %%
sns.set_context("talk")
sns.set_style("ticks")
sns.lineplot(x = "Yellow cards", y = "Fouls", data=df)
plt.show()

# %%
#ADVANCED ploting
sns.distplot(df['Age'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\2598101120.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Fouls'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\1091377954.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fouls'])
# <Axes: xlabel='Fouls', ylabel='Density'>

# %%
sns.kdeplot(data=df['Passes per match'], 
shade=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\3670066824.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df['Passes per match'],
# <Axes: xlabel='Passes per match', ylabel='Density'>

# %%
sns.kdeplot(data=df['Clean sheets'], 
shade=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2024\3672125800.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df['Clean sheets'],
# <Axes: xlabel='Clean sheets', ylabel='Density'>

# %%
sns.rugplot(df['Goals conceded'])
# Out:
# <Axes: xlabel='Goals conceded'>

# %%
sns.rugplot(df['Freekicks scored'])
# Out:
# <Axes: xlabel='Freekicks scored'>

# %%
# Example of using boxplot
sns.boxplot(x ='Position', y='Losses', data=df)
# Out:
# <Axes: xlabel='Position', ylabel='Losses'>

# %%
# Example of using boxplot
plt.figure(figsize=(10,5))
sns.boxplot(x='Club', y='Jersey Number', color = 'green' ,data=df.head(115))
# Out:
# <Axes: xlabel='Club', ylabel='Jersey Number'>

# %%
# Example of using violinplot
plt.figure(figsize=(12,6))
sns.violinplot(x='Club', y='Freekicks scored', data=df.head(113))
# Out:
# <Axes: xlabel='Club', ylabel='Freekicks scored'>

# %%
# Example of using violinplot
plt.figure(figsize=(12,5))

sns.violinplot(x='Club', y='Freekicks scored', color = 'red' , data=df.head(115))
# Out:
# <Axes: xlabel='Club', ylabel='Freekicks scored'>

# %%
# Example of using swarmplot
plt.figure(figsize=(12,5))
sns.swarmplot(x='Club', y='Freekicks scored', data=df.head(115))
# Out:
# <Axes: xlabel='Club', ylabel='Freekicks scored'>

# %%
# Example of using swarmplot
plt.figure(figsize=(12,5))
sns.swarmplot(x='Club', y='Goals per match', data=df.head(115))
# Out:
# <Axes: xlabel='Club', ylabel='Goals per match'>

# %%
# Example of using jointplot
sns.jointplot(x='Shots', y='Freekicks scored', data=df, kind='scatter')

# %%
# Example of using jointplot
sns.jointplot(x='Age', y='Wins', data=df, kind='scatter')

# %%
# Example of using pairplot
born.pairplot(df.head(30), hue='Names')
